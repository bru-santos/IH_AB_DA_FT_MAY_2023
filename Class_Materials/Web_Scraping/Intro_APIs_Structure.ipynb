# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '30205608196',
#   'type': 'PushEvent',
#   'actor': {'id': 4139601,
#    'login': 'CaF2',
#    'display_login': 'CaF2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CaF2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4139601?'},
#   'repo': {'id': 661710037,
#    'name': 'CaF2/tensorflow_capi_sample',
#    'url': 'https://api.github.com/repos/CaF2/tensorflow_capi_sample'},
#   'payload': {'repository_id': 661710037,
#    'push_id': 14211142400,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a354d95b6119b93c836b172ec861a94aa4591a31',
#    'before': 'ba93346860ce577bbcbf61a8754ee5fe03f7ad3b',
#    'commits': [{'sha': 'a354d95b6119b93c836b172ec861a94aa4591a31',
#      'author': {'email': 'florian.evaldsson@telia.com',
#       'name': 'Florian Evaldsson'},
#      'message': 'split them up into two examples',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CaF2/tensorflow_capi_sample/commits/a354d95b6119b93c836b172ec861a94aa4591a31'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608154',
#   'type': 'PushEvent',
#   'actor': {'id': 109524200,
#    'login': 'Pragna235',
#    'display_login': 'Pragna235',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Pragna235',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109524200?'},
#   'repo': {'id': 661281119,
#    'name': 'Pragna235/InterviewBit',
#    'url': 'https://api.github.com/repos/Pragna235/InterviewBit'},
#   'payload': {'repository_id': 661281119,
#    'push_id': 14211142387,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c327db4a8d774feae9cd0b46bb91230e6530c2f3',
#    'before': '9e58dcaaf6bb479c268d6514889716b23dd762aa',
#    'commits': [{'sha': 'c327db4a8d774feae9cd0b46bb91230e6530c2f3',
#      'author': {'email': '109524200+Pragna235@users.noreply.github.com',
#       'name': 'Pragna Yanduri'},
#      'message': 'Create Number of 1 bits.cpp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pragna235/InterviewBit/commits/c327db4a8d774feae9cd0b46bb91230e6530c2f3'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608153',
#   'type': 'PushEvent',
#   'actor': {'id': 120438850,
#    'login': '19920513',
#    'display_login': '19920513',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/19920513',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120438850?'},
#   'repo': {'id': 583675202,
#    'name': '19920513/www',
#    'url': 'https://api.github.com/repos/19920513/www'},
#   'payload': {'repository_id': 583675202,
#    'push_id': 14211142391,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7389ce3386fe362ee1f52faaa61b9430a95fb35d',
#    'before': 'a18c9b1c1220253c8fa7bc0b6655dbfd9fb12a00',
#    'commits': [{'sha': '7389ce3386fe362ee1f52faaa61b9430a95fb35d',
#      'author': {'email': '120438850+19920513@users.noreply.github.com',
#       'name': '19920513'},
#      'message': 'Update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/19920513/www/commits/7389ce3386fe362ee1f52faaa61b9430a95fb35d'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608214',
#   'type': 'CreateEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 522779339,
#    'name': 'curseforge-mirror/rclootcouncil',
#    'url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil'},
#   'payload': {'ref': 'v2023.07.05.09.13',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': "Mirror of evil_morfar's RCLootCouncil.",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 110800464,
#    'login': 'curseforge-mirror',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/curseforge-mirror',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110800464?'}},
#  {'id': '30205608197',
#   'type': 'CreateEvent',
#   'actor': {'id': 23467024,
#    'login': 'heungheung',
#    'display_login': 'heungheung',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heungheung',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23467024?'},
#   'repo': {'id': 662499999,
#    'name': 'oci-sunbird/ocisunbird-sunbird-core-dataproducts',
#    'url': 'https://api.github.com/repos/oci-sunbird/ocisunbird-sunbird-core-dataproducts'},
#   'payload': {'ref': 'release-2.10.1',
#    'ref_type': 'branch',
#    'master_branch': 'amorphous-1-patch-1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 133922262,
#    'login': 'oci-sunbird',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/oci-sunbird',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133922262?'}},
#  {'id': '30205608090',
#   'type': 'PushEvent',
#   'actor': {'id': 66510055,
#    'login': 'nikhanal',
#    'display_login': 'nikhanal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nikhanal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66510055?'},
#   'repo': {'id': 662294388,
#    'name': 'nikhanal/tcioe-node',
#    'url': 'https://api.github.com/repos/nikhanal/tcioe-node'},
#   'payload': {'repository_id': 662294388,
#    'push_id': 14211142317,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/main',
#    'head': 'b90742e42ec14b778736d811ec27810d3099a963',
#    'before': '6ab734f6b7a8712f7ec60a337431e2a54dd53af3',
#    'commits': [{'sha': '34f13f5ffb88ba883c1a95df64a922f26ac2309c',
#      'author': {'email': '66164291+ompiepy@users.noreply.github.com',
#       'name': 'Om Prakash Sharma'},
#      'message': 'Merge pull request #1 from nikhanal/main\n\nadded academic programs pages and added reports',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/34f13f5ffb88ba883c1a95df64a922f26ac2309c'},
#     {'sha': 'f7fee212ad38765d293326053a949309973de802',
#      'author': {'email': 'prateekpoudel61@gmail.com', 'name': 'Prateek61'},
#      'message': 'Implemented research facilities pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/f7fee212ad38765d293326053a949309973de802'},
#     {'sha': '8c949c8a5f5c0ef37b973a9e21f0632400edb025',
#      'author': {'email': 'prateekpoudel61@gmail.com', 'name': 'Prateek61'},
#      'message': 'merged',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/8c949c8a5f5c0ef37b973a9e21f0632400edb025'},
#     {'sha': '859b3ff815ec249440e812b8b84e5c12d624179d',
#      'author': {'email': '66164291+ompiepy@users.noreply.github.com',
#       'name': 'Om Prakash Sharma'},
#      'message': 'Merge pull request #2 from Prateek61/main\n\nimplemented research facilities section',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/859b3ff815ec249440e812b8b84e5c12d624179d'},
#     {'sha': '32cbbf77f66a5749678b5db347da2ef01db15a65',
#      'author': {'email': '66164291+ompiepy@users.noreply.github.com',
#       'name': 'Om Prakash Sharma'},
#      'message': 'added dspace and check mail to submenu bar Minor issues #5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/32cbbf77f66a5749678b5db347da2ef01db15a65'},
#     {'sha': 'b90742e42ec14b778736d811ec27810d3099a963',
#      'author': {'email': '66164291+ompiepy@users.noreply.github.com',
#       'name': 'Om Prakash Sharma'},
#      'message': 'Merge pull request #20 from ompiepy/main\n\nadded dspace and check mail to submenu bar Minor issues #5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikhanal/tcioe-node/commits/b90742e42ec14b778736d811ec27810d3099a963'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608181',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 47170309,
#    'login': 'ybbthou8',
#    'display_login': 'ybbthou8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ybbthou8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47170309?'},
#   'repo': {'id': 552661142,
#    'name': 'hwchase17/langchain',
#    'url': 'https://api.github.com/repos/hwchase17/langchain'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135',
#     'repository_url': 'https://api.github.com/repos/hwchase17/langchain',
#     'labels_url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135/comments',
#     'events_url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135/events',
#     'html_url': 'https://github.com/hwchase17/langchain/issues/7135',
#     'id': 1787553988,
#     'node_id': 'I_kwDOIPDwls5qi-jE',
#     'number': 7135,
#     'title': '"ConversationBufferMemory" object has no field "buffer" ',
#     'user': {'login': 'ybbthou8',
#      'id': 47170309,
#      'node_id': 'MDQ6VXNlcjQ3MTcwMzA5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/47170309?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ybbthou8',
#      'html_url': 'https://github.com/ybbthou8',
#      'followers_url': 'https://api.github.com/users/ybbthou8/followers',
#      'following_url': 'https://api.github.com/users/ybbthou8/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ybbthou8/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ybbthou8/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ybbthou8/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ybbthou8/orgs',
#      'repos_url': 'https://api.github.com/users/ybbthou8/repos',
#      'events_url': 'https://api.github.com/users/ybbthou8/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ybbthou8/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 5680700839,
#       'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#       'url': 'https://api.github.com/repos/hwchase17/langchain/labels/auto:bug',
#       'name': 'auto:bug',
#       'color': 'E99695',
#       'default': False,
#       'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2023-07-04T09:36:49Z',
#     'updated_at': '2023-07-05T09:13:36Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '### System Info\n\n0.0.220\n\n### Who can help?\n\n_No response_\n\n### Information\n\n- [ ] The official example notebooks/scripts\n- [ ] My own modified scripts\n\n### Related Components\n\n- [ ] LLMs/Chat Models\n- [ ] Embedding Models\n- [ ] Prompts / Prompt Templates / Prompt Selectors\n- [ ] Output Parsers\n- [ ] Document Loaders\n- [ ] Vector Stores / Retrievers\n- [ ] Memory\n- [ ] Agents / Agent Executors\n- [ ] Tools / Toolkits\n- [ ] Chains\n- [ ] Callbacks/Tracing\n- [ ] Async\n\n### Reproduction\n\nself.memory = ConversationBufferMemory(memory_key="chat_history", output_key=\'output\')\r\nself.agent.memory.buffer = self.agent.memory.buffer + Human_prompt + \'AI: \' + AI_prompt\n\n### Expected behavior\n\nno error output',
#     'reactions': {'url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135/reactions',
#      'total_count': 1,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 1},
#     'timeline_url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/hwchase17/langchain/issues/comments/1621352032',
#     'html_url': 'https://github.com/hwchase17/langchain/issues/7135#issuecomment-1621352032',
#     'issue_url': 'https://api.github.com/repos/hwchase17/langchain/issues/7135',
#     'id': 1621352032,
#     'node_id': 'IC_kwDOIPDwls5go95g',
#     'user': {'login': 'ybbthou8',
#      'id': 47170309,
#      'node_id': 'MDQ6VXNlcjQ3MTcwMzA5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/47170309?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ybbthou8',
#      'html_url': 'https://github.com/ybbthou8',
#      'followers_url': 'https://api.github.com/users/ybbthou8/followers',
#      'following_url': 'https://api.github.com/users/ybbthou8/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ybbthou8/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ybbthou8/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ybbthou8/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ybbthou8/orgs',
#      'repos_url': 'https://api.github.com/users/ybbthou8/repos',
#      'events_url': 'https://api.github.com/users/ybbthou8/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ybbthou8/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-07-05T09:13:36Z',
#     'updated_at': '2023-07-05T09:13:36Z',
#     'author_association': 'NONE',
#     'body': '> I\'m not sure what you\'re trying to do but you have created the `ConversationBufferMemory `and stored it in `self.memory`, if you want to access the buffer property of the `ConversationBufferMemory` shouldn\'t you refer to `self.memory.buffer`?\r\n\r\nI may need to add the relationship between the two memories：\r\n        self.agent = initialize_agent(\r\n            self.tools,\r\n            self.llm,\r\n            agent="conversational-react-description",#AgentType.CONVERSATIONAL_REACT_DESCRIPTION,\r\n            verbose=True,\r\n            memory=self.memory,\r\n            return_intermediate_steps=True,\r\n            agent_kwargs={\'prefix\': PREFIX, \'format_instructions\': FORMAT_INSTRUCTIONS,\r\n                          \'suffix\': SUFFIX}, \r\n        )\r\nso in my point, self.agnet.memory and self.memory are the same object.',
#     'reactions': {'url': 'https://api.github.com/repos/hwchase17/langchain/issues/comments/1621352032/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608066',
#   'type': 'PushEvent',
#   'actor': {'id': 26748221,
#    'login': 'Selfeer',
#    'display_login': 'Selfeer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Selfeer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26748221?'},
#   'repo': {'id': 530821975,
#    'name': 'Altinity/clickhouse-regression',
#    'url': 'https://api.github.com/repos/Altinity/clickhouse-regression'},
#   'payload': {'repository_id': 530821975,
#    'push_id': 14211142322,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '25dca70611623527835e1adc6d27282fc1c467a0',
#    'before': '6cd2a59ffabc9acfc1f1175b82615ddae837e831',
#    'commits': [{'sha': '25dca70611623527835e1adc6d27282fc1c467a0',
#      'author': {'email': 'selfeers@gmail.com', 'name': 'selfeer'},
#      'message': 'add requirements about multi directory glob',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Altinity/clickhouse-regression/commits/25dca70611623527835e1adc6d27282fc1c467a0'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 28471076,
#    'login': 'Altinity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Altinity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28471076?'}},
#  {'id': '30205608139',
#   'type': 'PushEvent',
#   'actor': {'id': 97634377,
#    'login': 'h4mz411y',
#    'display_login': 'h4mz411y',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/h4mz411y',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97634377?'},
#   'repo': {'id': 662492653,
#    'name': 'h4mz411y/OrangeTask-FE-CSS',
#    'url': 'https://api.github.com/repos/h4mz411y/OrangeTask-FE-CSS'},
#   'payload': {'repository_id': 662492653,
#    'push_id': 14211142342,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '809141f3a7d13c55ecdcb25d81f03be597f74f16',
#    'before': '5c84bef402eb5a74f9fc4a5935c3502943934db9',
#    'commits': [{'sha': '809141f3a7d13c55ecdcb25d81f03be597f74f16',
#      'author': {'email': 'hamzabashar93@yahoo.com', 'name': 'h4mz411y'},
#      'message': 'MVP',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/h4mz411y/OrangeTask-FE-CSS/commits/809141f3a7d13c55ecdcb25d81f03be597f74f16'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608147',
#   'type': 'PushEvent',
#   'actor': {'id': 120438850,
#    'login': '19920513',
#    'display_login': '19920513',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/19920513',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120438850?'},
#   'repo': {'id': 583677093,
#    'name': '19920513/ntdtv',
#    'url': 'https://api.github.com/repos/19920513/ntdtv'},
#   'payload': {'repository_id': 583677093,
#    'push_id': 14211142385,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '247936ce6fca49d78a1e2812fc0a53dbfe1fb97c',
#    'before': 'fe9d4995bf0bb60b9fd6c4f9b2068bb0da375ef0',
#    'commits': [{'sha': '247936ce6fca49d78a1e2812fc0a53dbfe1fb97c',
#      'author': {'email': '120438850+19920513@users.noreply.github.com',
#       'name': '19920513'},
#      'message': 'Update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/19920513/ntdtv/commits/247936ce6fca49d78a1e2812fc0a53dbfe1fb97c'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608076',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 613363386,
#    'name': 'ZwierzchowskiM/ZwierzchowskiM',
#    'url': 'https://api.github.com/repos/ZwierzchowskiM/ZwierzchowskiM'},
#   'payload': {'repository_id': 613363386,
#    'push_id': 14211142325,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '8f60074a267a864703460437ba5581c24ef732f5',
#    'before': 'a8a0b35036eddaecf3767358a4479a710f9adb45',
#    'commits': [{'sha': '8f60074a267a864703460437ba5581c24ef732f5',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZwierzchowskiM/ZwierzchowskiM/commits/8f60074a267a864703460437ba5581c24ef732f5'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608121',
#   'type': 'PushEvent',
#   'actor': {'id': 133202042,
#    'login': 'Haelios',
#    'display_login': 'Haelios',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Haelios',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133202042?'},
#   'repo': {'id': 648803933,
#    'name': 'Haelios/Projet_7_OC',
#    'url': 'https://api.github.com/repos/Haelios/Projet_7_OC'},
#   'payload': {'repository_id': 648803933,
#    'push_id': 14211142356,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0af29b574cac3e6624b9935fce098ddf823645f7',
#    'before': '46110bb260119e76013c8229d81a0eb683e6edd1',
#    'commits': [{'sha': '0af29b574cac3e6624b9935fce098ddf823645f7',
#      'author': {'email': '133202042+Haelios@users.noreply.github.com',
#       'name': 'Haelios'},
#      'message': 'Delete data_test_sample.csv',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Haelios/Projet_7_OC/commits/0af29b574cac3e6624b9935fce098ddf823645f7'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608129',
#   'type': 'PushEvent',
#   'actor': {'id': 83652913,
#    'login': 'timazloy',
#    'display_login': 'timazloy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/timazloy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83652913?'},
#   'repo': {'id': 659197746,
#    'name': 'timazloy/React-pizza',
#    'url': 'https://api.github.com/repos/timazloy/React-pizza'},
#   'payload': {'repository_id': 659197746,
#    'push_id': 14211142378,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '56baffce70829f0bc8d618fd7670e1a47b7682f9',
#    'before': '6f2b6b12ac21a97181b8091d82728f7f557a692a',
#    'commits': [{'sha': '56baffce70829f0bc8d618fd7670e1a47b7682f9',
#      'author': {'email': 'timazloy04444@gmail.com', 'name': 'Timazlo'},
#      'message': 'add: cart component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/timazloy/React-pizza/commits/56baffce70829f0bc8d618fd7670e1a47b7682f9'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608146',
#   'type': 'CreateEvent',
#   'actor': {'id': 138666143,
#    'login': 'Dimablock69',
#    'display_login': 'Dimablock69',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dimablock69',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138666143?'},
#   'repo': {'id': 662500387,
#    'name': 'Dimablock69/1',
#    'url': 'https://api.github.com/repos/Dimablock69/1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608123',
#   'type': 'PushEvent',
#   'actor': {'id': 100561809,
#    'login': 'T4O6N',
#    'display_login': 'T4O6N',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/T4O6N',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100561809?'},
#   'repo': {'id': 662408234,
#    'name': 'T4O6N/payroll-c-',
#    'url': 'https://api.github.com/repos/T4O6N/payroll-c-'},
#   'payload': {'repository_id': 662408234,
#    'push_id': 14211142377,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8a138d7bcf7f0f563f1eb98a2fa329a7e98bd936',
#    'before': '7b2c086f755470f4d0ff8f71d7a32b27b7aea625',
#    'commits': [{'sha': '8a138d7bcf7f0f563f1eb98a2fa329a7e98bd936',
#      'author': {'email': 'Asus TUF@LAPTOP-VPACFSN0', 'name': 'Asus TUF'},
#      'message': 'cm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/T4O6N/payroll-c-/commits/8a138d7bcf7f0f563f1eb98a2fa329a7e98bd936'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608128',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1786669,
#    'login': 'Jojo-Schmitz',
#    'display_login': 'Jojo-Schmitz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jojo-Schmitz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1786669?'},
#   'repo': {'id': 4454793,
#    'name': 'musescore/MuseScore',
#    'url': 'https://api.github.com/repos/musescore/MuseScore'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191',
#     'repository_url': 'https://api.github.com/repos/musescore/MuseScore',
#     'labels_url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191/comments',
#     'events_url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191/events',
#     'html_url': 'https://github.com/musescore/MuseScore/pull/18191',
#     'id': 1774753835,
#     'node_id': 'PR_kwDOAEP5ic5T604A',
#     'number': 18191,
#     'title': 'Fix #293441: [MusicXML export] invalid XML export: direction-type is missing child element',
#     'user': {'login': 'Jojo-Schmitz',
#      'id': 1786669,
#      'node_id': 'MDQ6VXNlcjE3ODY2Njk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1786669?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Jojo-Schmitz',
#      'html_url': 'https://github.com/Jojo-Schmitz',
#      'followers_url': 'https://api.github.com/users/Jojo-Schmitz/followers',
#      'following_url': 'https://api.github.com/users/Jojo-Schmitz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Jojo-Schmitz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Jojo-Schmitz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Jojo-Schmitz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Jojo-Schmitz/orgs',
#      'repos_url': 'https://api.github.com/users/Jojo-Schmitz/repos',
#      'events_url': 'https://api.github.com/users/Jojo-Schmitz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Jojo-Schmitz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2023-06-26T13:11:40Z',
#     'updated_at': '2023-07-05T09:13:36Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/musescore/MuseScore/pulls/18191',
#      'html_url': 'https://github.com/musescore/MuseScore/pull/18191',
#      'diff_url': 'https://github.com/musescore/MuseScore/pull/18191.diff',
#      'patch_url': 'https://github.com/musescore/MuseScore/pull/18191.patch',
#      'merged_at': None},
#     'body': 'See #18056',
#     'reactions': {'url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/musescore/MuseScore/issues/comments/1621352027',
#     'html_url': 'https://github.com/musescore/MuseScore/pull/18191#issuecomment-1621352027',
#     'issue_url': 'https://api.github.com/repos/musescore/MuseScore/issues/18191',
#     'id': 1621352027,
#     'node_id': 'IC_kwDOAEP5ic5go95b',
#     'user': {'login': 'Jojo-Schmitz',
#      'id': 1786669,
#      'node_id': 'MDQ6VXNlcjE3ODY2Njk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1786669?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Jojo-Schmitz',
#      'html_url': 'https://github.com/Jojo-Schmitz',
#      'followers_url': 'https://api.github.com/users/Jojo-Schmitz/followers',
#      'following_url': 'https://api.github.com/users/Jojo-Schmitz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Jojo-Schmitz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Jojo-Schmitz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Jojo-Schmitz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Jojo-Schmitz/orgs',
#      'repos_url': 'https://api.github.com/users/Jojo-Schmitz/repos',
#      'events_url': 'https://api.github.com/users/Jojo-Schmitz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Jojo-Schmitz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-07-05T09:13:35Z',
#     'updated_at': '2023-07-05T09:13:35Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'as #18056 is in master now, this may make it into 4.1.0 ;-)',
#     'reactions': {'url': 'https://api.github.com/repos/musescore/MuseScore/issues/comments/1621352027/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 380563,
#    'login': 'musescore',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/musescore',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/380563?'}},
#  {'id': '30205608064',
#   'type': 'CreateEvent',
#   'actor': {'id': 138441805,
#    'login': 'topsberwite',
#    'display_login': 'topsberwite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topsberwite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138441805?'},
#   'repo': {'id': 662500384,
#    'name': 'topsberwite/Mondrian-Painting-Project',
#    'url': 'https://api.github.com/repos/topsberwite/Mondrian-Painting-Project'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'a simple project using grids',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608042',
#   'type': 'PushEvent',
#   'actor': {'id': 125555048,
#    'login': 'khaoula-berrah',
#    'display_login': 'khaoula-berrah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/khaoula-berrah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125555048?'},
#   'repo': {'id': 649686746,
#    'name': 'khaoula-berrah/alx-higher_level_programming',
#    'url': 'https://api.github.com/repos/khaoula-berrah/alx-higher_level_programming'},
#   'payload': {'repository_id': 649686746,
#    'push_id': 14211142337,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4cb5cd319f2d2f0bbe316b101a89cfe55b4a8f83',
#    'before': '217974fc822a3c1c581e0344bb867d9577b4d5c8',
#    'commits': [{'sha': '4cb5cd319f2d2f0bbe316b101a89cfe55b4a8f83',
#      'author': {'email': 'berah.khaoula@gmail.com', 'name': 'khaoula-berrah'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/khaoula-berrah/alx-higher_level_programming/commits/4cb5cd319f2d2f0bbe316b101a89cfe55b4a8f83'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608092',
#   'type': 'WatchEvent',
#   'actor': {'id': 81730001,
#    'login': 'lhsnam',
#    'display_login': 'lhsnam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lhsnam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81730001?'},
#   'repo': {'id': 201089574,
#    'name': 'pfasante/phd_thesis',
#    'url': 'https://api.github.com/repos/pfasante/phd_thesis'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608068',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 5378891,
#    'login': 'zombieJ',
#    'display_login': 'zombieJ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zombieJ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5378891?'},
#   'repo': {'id': 47093357,
#    'name': 'ant-design/ant-design-mobile',
#    'url': 'https://api.github.com/repos/ant-design/ant-design-mobile'},
#   'payload': {'action': 'created',
#    'review': {'id': 1514050910,
#     'node_id': 'PRR_kwDOAs6Wbc5aPpVe',
#     'user': {'login': 'zombieJ',
#      'id': 5378891,
#      'node_id': 'MDQ6VXNlcjUzNzg4OTE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5378891?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zombieJ',
#      'html_url': 'https://github.com/zombieJ',
#      'followers_url': 'https://api.github.com/users/zombieJ/followers',
#      'following_url': 'https://api.github.com/users/zombieJ/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zombieJ/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zombieJ/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zombieJ/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zombieJ/orgs',
#      'repos_url': 'https://api.github.com/users/zombieJ/repos',
#      'events_url': 'https://api.github.com/users/zombieJ/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zombieJ/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': 'df72c233c65b31e80a2e324ee4c24ba2d412ff2b',
#     'submitted_at': '2023-07-05T09:13:35Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/ant-design/ant-design-mobile/pull/6236#pullrequestreview-1514050910',
#     'pull_request_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/6236',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/ant-design/ant-design-mobile/pull/6236#pullrequestreview-1514050910'},
#      'pull_request': {'href': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/6236'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/6236',
#     'id': 1420577397,
#     'node_id': 'PR_kwDOAs6Wbc5UrEp1',
#     'html_url': 'https://github.com/ant-design/ant-design-mobile/pull/6236',
#     'diff_url': 'https://github.com/ant-design/ant-design-mobile/pull/6236.diff',
#     'patch_url': 'https://github.com/ant-design/ant-design-mobile/pull/6236.patch',
#     'issue_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/issues/6236',
#     'number': 6236,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat(DatePickerView): support till now',
#     'user': {'login': 'miracles1919',
#      'id': 22469543,
#      'node_id': 'MDQ6VXNlcjIyNDY5NTQz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/22469543?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/miracles1919',
#      'html_url': 'https://github.com/miracles1919',
#      'followers_url': 'https://api.github.com/users/miracles1919/followers',
#      'following_url': 'https://api.github.com/users/miracles1919/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/miracles1919/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/miracles1919/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/miracles1919/subscriptions',
#      'organizations_url': 'https://api.github.com/users/miracles1919/orgs',
#      'repos_url': 'https://api.github.com/users/miracles1919/repos',
#      'events_url': 'https://api.github.com/users/miracles1919/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/miracles1919/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'https://github.com/ant-design/ant-design-mobile/issues/6137#issuecomment-1546591413',
#     'created_at': '2023-07-05T07:35:59Z',
#     'updated_at': '2023-07-05T09:13:35Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'cb0d1ab9a5aae426cf50b06125fbb13dd2726365',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/6236/commits',
#     'review_comments_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/6236/comments',
#     'review_comment_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/issues/6236/comments',
#     'statuses_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/statuses/df72c233c65b31e80a2e324ee4c24ba2d412ff2b',
#     'head': {'label': 'miracles1919:feat/till-now',
#      'ref': 'feat/till-now',
#      'sha': 'df72c233c65b31e80a2e324ee4c24ba2d412ff2b',
#      'user': {'login': 'miracles1919',
#       'id': 22469543,
#       'node_id': 'MDQ6VXNlcjIyNDY5NTQz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/22469543?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/miracles1919',
#       'html_url': 'https://github.com/miracles1919',
#       'followers_url': 'https://api.github.com/users/miracles1919/followers',
#       'following_url': 'https://api.github.com/users/miracles1919/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/miracles1919/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/miracles1919/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/miracles1919/subscriptions',
#       'organizations_url': 'https://api.github.com/users/miracles1919/orgs',
#       'repos_url': 'https://api.github.com/users/miracles1919/repos',
#       'events_url': 'https://api.github.com/users/miracles1919/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/miracles1919/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 409190238,
#       'node_id': 'R_kgDOGGO_Xg',
#       'name': 'ant-design-mobile',
#       'full_name': 'miracles1919/ant-design-mobile',
#       'private': False,
#       'owner': {'login': 'miracles1919',
#        'id': 22469543,
#        'node_id': 'MDQ6VXNlcjIyNDY5NTQz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/22469543?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/miracles1919',
#        'html_url': 'https://github.com/miracles1919',
#        'followers_url': 'https://api.github.com/users/miracles1919/followers',
#        'following_url': 'https://api.github.com/users/miracles1919/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/miracles1919/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/miracles1919/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/miracles1919/subscriptions',
#        'organizations_url': 'https://api.github.com/users/miracles1919/orgs',
#        'repos_url': 'https://api.github.com/users/miracles1919/repos',
#        'events_url': 'https://api.github.com/users/miracles1919/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/miracles1919/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/miracles1919/ant-design-mobile',
#       'description': 'A configurable Mobile UI',
#       'fork': True,
#       'url': 'https://api.github.com/repos/miracles1919/ant-design-mobile',
#       'forks_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/forks',
#       'keys_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/teams',
#       'hooks_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/hooks',
#       'issue_events_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/events',
#       'assignees_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/tags',
#       'blobs_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/languages',
#       'stargazers_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/stargazers',
#       'contributors_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/contributors',
#       'subscribers_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/subscribers',
#       'subscription_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/subscription',
#       'commits_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/merges',
#       'archive_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/downloads',
#       'issues_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/miracles1919/ant-design-mobile/deployments',
#       'created_at': '2021-09-22T12:10:31Z',
#       'updated_at': '2022-12-14T06:51:35Z',
#       'pushed_at': '2023-07-05T07:35:25Z',
#       'git_url': 'git://github.com/miracles1919/ant-design-mobile.git',
#       'ssh_url': 'git@github.com:miracles1919/ant-design-mobile.git',
#       'clone_url': 'https://github.com/miracles1919/ant-design-mobile.git',
#       'svn_url': 'https://github.com/miracles1919/ant-design-mobile',
#       'homepage': 'https://next.mobile.ant.design',
#       'size': 117350,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'ant-design:feature',
#      'ref': 'feature',
#      'sha': '2a78b4bdf5b5563d7872c42774b28de4a2087702',
#      'user': {'login': 'ant-design',
#       'id': 12101536,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMTAxNTM2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12101536?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ant-design',
#       'html_url': 'https://github.com/ant-design',
#       'followers_url': 'https://api.github.com/users/ant-design/followers',
#       'following_url': 'https://api.github.com/users/ant-design/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ant-design/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ant-design/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ant-design/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ant-design/orgs',
#       'repos_url': 'https://api.github.com/users/ant-design/repos',
#       'events_url': 'https://api.github.com/users/ant-design/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ant-design/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 47093357,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NzA5MzM1Nw==',
#       'name': 'ant-design-mobile',
#       'full_name': 'ant-design/ant-design-mobile',
#       'private': False,
#       'owner': {'login': 'ant-design',
#        'id': 12101536,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMTAxNTM2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12101536?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ant-design',
#        'html_url': 'https://github.com/ant-design',
#        'followers_url': 'https://api.github.com/users/ant-design/followers',
#        'following_url': 'https://api.github.com/users/ant-design/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ant-design/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ant-design/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ant-design/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ant-design/orgs',
#        'repos_url': 'https://api.github.com/users/ant-design/repos',
#        'events_url': 'https://api.github.com/users/ant-design/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ant-design/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ant-design/ant-design-mobile',
#       'description': 'Essential UI blocks for building mobile web apps.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ant-design/ant-design-mobile',
#       'forks_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/forks',
#       'keys_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/teams',
#       'hooks_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/events',
#       'assignees_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/tags',
#       'blobs_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/languages',
#       'stargazers_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/subscription',
#       'commits_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ant-design/ant-design-mobile/git/commits{/sha}',
# ...
#      'following_url': 'https://api.github.com/users/enjikaka/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/enjikaka/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/enjikaka/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/enjikaka/subscriptions',
#      'organizations_url': 'https://api.github.com/users/enjikaka/orgs',
#      'repos_url': 'https://api.github.com/users/enjikaka/repos',
#      'events_url': 'https://api.github.com/users/enjikaka/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/enjikaka/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-07-05T09:13:35Z',
#     'updated_at': '2023-07-05T09:13:35Z',
#     'author_association': 'NONE',
#     'body': '> Is anyone interested in this functionality?\r\n\r\nYes, 257 %! Needed for gapless playback :)',
#     'reactions': {'url': 'https://api.github.com/repos/shaka-project/shaka-player/issues/comments/1621352020/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 99903801,
#    'login': 'shaka-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/shaka-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99903801?'}},
#  {'id': '30205608023',
#   'type': 'PushEvent',
#   'actor': {'id': 95530911,
#    'login': 'etherealelement',
#    'display_login': 'etherealelement',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/etherealelement',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95530911?'},
#   'repo': {'id': 624092546,
#    'name': 'etherealelement/rsschool-cv',
#    'url': 'https://api.github.com/repos/etherealelement/rsschool-cv'},
#   'payload': {'repository_id': 624092546,
#    'push_id': 14211142298,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/rsschool-cv-html',
#    'head': '5f74829fe53d349b90add56dda520a5d7e9d0256',
#    'before': 'fd5c1145bb50392e8db48402cb17c02854ee3440',
#    'commits': [{'sha': '929eaa460bf34bb3e62cf99e6aa290cb328d1ed4',
#      'author': {'email': 'vitalik.safonov@list.ru',
#       'name': 'ethereal element'},
#      'message': 'fix: fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/etherealelement/rsschool-cv/commits/929eaa460bf34bb3e62cf99e6aa290cb328d1ed4'},
#     {'sha': '5f74829fe53d349b90add56dda520a5d7e9d0256',
#      'author': {'email': 'vitalik.safonov@list.ru',
#       'name': 'ethereal element'},
#      'message': 'init: header',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/etherealelement/rsschool-cv/commits/5f74829fe53d349b90add56dda520a5d7e9d0256'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608021',
#   'type': 'PushEvent',
#   'actor': {'id': 106835730,
#    'login': 'TiffanyGB',
#    'display_login': 'TiffanyGB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TiffanyGB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106835730?'},
#   'repo': {'id': 657492571,
#    'name': 'TiffanyGB/myapp',
#    'url': 'https://api.github.com/repos/TiffanyGB/myapp'},
#   'payload': {'repository_id': 657492571,
#    'push_id': 14211142318,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c416db87be5418bf3ad8853b5735eb792f891bcf',
#    'before': '24d8b897f3424c5d6ef50085adfcb2479b7e44a3',
#    'commits': [{'sha': 'c416db87be5418bf3ad8853b5735eb792f891bcf',
#      'author': {'email': 'tiffany.gbellile@gmail.com', 'name': 'tiffanyGB'},
#      'message': 'modif bug',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TiffanyGB/myapp/commits/c416db87be5418bf3ad8853b5735eb792f891bcf'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205608079',
#   'type': 'CreateEvent',
#   'actor': {'id': 23467024,
#    'login': 'heungheung',
#    'display_login': 'heungheung',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heungheung',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23467024?'},
#   'repo': {'id': 662499999,
#    'name': 'oci-sunbird/ocisunbird-sunbird-core-dataproducts',
#    'url': 'https://api.github.com/repos/oci-sunbird/ocisunbird-sunbird-core-dataproducts'},
#   'payload': {'ref': 'release-3.1.0',
#    'ref_type': 'branch',
#    'master_branch': 'amorphous-1-patch-1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 133922262,
#    'login': 'oci-sunbird',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/oci-sunbird',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133922262?'}},
#  {'id': '30205608051',
#   'type': 'ForkEvent',
#   'actor': {'id': 35567571,
#    'login': 'lrgao',
#    'display_login': 'lrgao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lrgao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35567571?'},
#   'repo': {'id': 68287594,
#    'name': 'academicpages/academicpages.github.io',
#    'url': 'https://api.github.com/repos/academicpages/academicpages.github.io'},
#   'payload': {'forkee': {'id': 662500383,
#     'node_id': 'R_kgDOJ3z0Hw',
#     'name': 'lrgao.github.io',
#     'full_name': 'lrgao/lrgao.github.io',
#     'private': False,
#     'owner': {'login': 'lrgao',
#      'id': 35567571,
#      'node_id': 'MDQ6VXNlcjM1NTY3NTcx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/35567571?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lrgao',
#      'html_url': 'https://github.com/lrgao',
#      'followers_url': 'https://api.github.com/users/lrgao/followers',
#      'following_url': 'https://api.github.com/users/lrgao/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lrgao/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lrgao/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lrgao/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lrgao/orgs',
#      'repos_url': 'https://api.github.com/users/lrgao/repos',
#      'events_url': 'https://api.github.com/users/lrgao/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lrgao/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/lrgao/lrgao.github.io',
#     'description': 'Github Pages template for academic personal websites, forked from mmistakes/minimal-mistakes',
#     'fork': True,
#     'url': 'https://api.github.com/repos/lrgao/lrgao.github.io',
#     'forks_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/forks',
#     'keys_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/teams',
#     'hooks_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/hooks',
#     'issue_events_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/events',
#     'assignees_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/tags',
#     'blobs_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/languages',
#     'stargazers_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/stargazers',
#     'contributors_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/contributors',
#     'subscribers_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/subscribers',
#     'subscription_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/subscription',
#     'commits_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/merges',
#     'archive_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/downloads',
#     'issues_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/lrgao/lrgao.github.io/deployments',
#     'created_at': '2023-07-05T09:13:35Z',
#     'updated_at': '2023-07-05T09:13:35Z',
#     'pushed_at': '2023-07-05T01:53:37Z',
#     'git_url': 'git://github.com/lrgao/lrgao.github.io.git',
#     'ssh_url': 'git@github.com:lrgao/lrgao.github.io.git',
#     'clone_url': 'https://github.com/lrgao/lrgao.github.io.git',
#     'svn_url': 'https://github.com/lrgao/lrgao.github.io',
#     'homepage': 'https://academicpages.github.io',
#     'size': 51373,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 22107085,
#    'login': 'academicpages',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/academicpages',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22107085?'}},
#  {'id': '30205608027',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 562080230,
#    'name': 'mengisok/mengisok',
#    'url': 'https://api.github.com/repos/mengisok/mengisok'},
#   'payload': {'repository_id': 562080230,
#    'push_id': 14211142314,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '520d9dcdd483a51238dd0081ac094ec75f71b8bc',
#    'before': '9d39ad98f966287426fceb02f8cbb98dfd066f24',
#    'commits': [{'sha': '520d9dcdd483a51238dd0081ac094ec75f71b8bc',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mengisok/mengisok/commits/520d9dcdd483a51238dd0081ac094ec75f71b8bc'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z'},
#  {'id': '30205607988',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 522779339,
#    'name': 'curseforge-mirror/rclootcouncil',
#    'url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil/releases/111079142',
#     'assets_url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil/releases/111079142/assets',
#     'upload_url': 'https://uploads.github.com/repos/curseforge-mirror/rclootcouncil/releases/111079142/assets{?name,label}',
#     'html_url': 'https://github.com/curseforge-mirror/rclootcouncil/releases/tag/v2023.07.05.09.13',
#     'id': 111079142,
#     'author': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'node_id': 'RE_kwDOHyj6y84Gnu7m',
#     'tag_name': 'v2023.07.05.09.13',
#     'target_commitish': 'master',
#     'name': 'v2023.07.05.09.13',
#     'draft': False,
#     'prerelease': False,
#     'created_at': '2023-04-27T00:28:41Z',
#     'published_at': '2023-07-05T09:13:35Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil/tarball/v2023.07.05.09.13',
#     'zipball_url': 'https://api.github.com/repos/curseforge-mirror/rclootcouncil/zipball/v2023.07.05.09.13',
#     'body': "# RCLootCouncil Mirror\n\nThis is a mirror of evil_morfar's RCLootCouncil\n\n- [Curseforge URL](https://www.curseforge.com/wow/addons/rclootcouncil)\n\n----\n\nTo open a ticket related to this repository, please do so on [this repository](https://github.com/curseforge-mirror/.github)",
#     'short_description_html': '<h1>RCLootCouncil Mirror</h1>\n<p>This is a mirror of evil_morfar\'s RCLootCouncil</p>\n<ul>\n<li><a href="https://www.curseforge.com/wow/addons/rclootcouncil" rel="nofollow">Curseforge URL</a></li>\n</ul>\n<hr>\n<p>To open a ticket related to this repository, please do so on <a href="https://github.com/curseforge-mirror/.github">this repository</a></p>',
#     'is_short_description_html_truncated': False}},
#   'public': True,
#   'created_at': '2023-07-05T09:13:36Z',
#   'org': {'id': 110800464,
#    'login': 'curseforge-mirror',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/curseforge-mirror',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110800464?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                    type  \
# 0   30205608196               PushEvent
# 1   30205608154               PushEvent
# 2   30205608153               PushEvent
# 3   30205608214             CreateEvent
# 4   30205608197             CreateEvent
# 5   30205608090               PushEvent
# 6   30205608181       IssueCommentEvent
# 7   30205608066               PushEvent
# 8   30205608139               PushEvent
# 9   30205608147               PushEvent
# 10  30205608076               PushEvent
# 11  30205608121               PushEvent
# 12  30205608129               PushEvent
# 13  30205608146             CreateEvent
# 14  30205608123               PushEvent
# 15  30205608128       IssueCommentEvent
# 16  30205608064             CreateEvent
# 17  30205608042               PushEvent
# 18  30205608092              WatchEvent
# 19  30205608068  PullRequestReviewEvent
# 20  30205608046               PushEvent
# 21  30205608119        PullRequestEvent
# 22  30205608038               PushEvent
# 23  30205608006       IssueCommentEvent
# 24  30205608023               PushEvent
# 25  30205608021               PushEvent
# 26  30205608079             CreateEvent
# 27  30205608051               ForkEvent
# 28  30205608027               PushEvent
# 29  30205607988            ReleaseEvent
#
#                                                 actor  \
# 0   {'id': 4139601, 'login': 'CaF2', 'display_logi...
# 1   {'id': 109524200, 'login': 'Pragna235', 'displ...
# 2   {'id': 120438850, 'login': '19920513', 'displa...
# 3   {'id': 41898282, 'login': 'github-actions[bot]...
# 4   {'id': 23467024, 'login': 'heungheung', 'displ...
# 5   {'id': 66510055, 'login': 'nikhanal', 'display...
# 6   {'id': 47170309, 'login': 'ybbthou8', 'display...
# 7   {'id': 26748221, 'login': 'Selfeer', 'display_...
# 8   {'id': 97634377, 'login': 'h4mz411y', 'display...
# 9   {'id': 120438850, 'login': '19920513', 'displa...
# 10  {'id': 41898282, 'login': 'github-actions[bot]...
# 11  {'id': 133202042, 'login': 'Haelios', 'display...
# 12  {'id': 83652913, 'login': 'timazloy', 'display...
# 13  {'id': 138666143, 'login': 'Dimablock69', 'dis...
# 14  {'id': 100561809, 'login': 'T4O6N', 'display_l...
# 15  {'id': 1786669, 'login': 'Jojo-Schmitz', 'disp...
# 16  {'id': 138441805, 'login': 'topsberwite', 'dis...
# 17  {'id': 125555048, 'login': 'khaoula-berrah', '...
# 18  {'id': 81730001, 'login': 'lhsnam', 'display_l...
# 19  {'id': 5378891, 'login': 'zombieJ', 'display_l...
# 20  {'id': 52900978, 'login': 'eunbinpark', 'displ...
# 21  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 22  {'id': 66510055, 'login': 'nikhanal', 'display...
# 23  {'id': 877455, 'login': 'enjikaka', 'display_l...
# 24  {'id': 95530911, 'login': 'etherealelement', '...
# 25  {'id': 106835730, 'login': 'TiffanyGB', 'displ...
# 26  {'id': 23467024, 'login': 'heungheung', 'displ...
# 27  {'id': 35567571, 'login': 'lrgao', 'display_lo...
# 28  {'id': 41898282, 'login': 'github-actions[bot]...
# 29  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                  repo  \
# 0   {'id': 661710037, 'name': 'CaF2/tensorflow_cap...
# 1   {'id': 661281119, 'name': 'Pragna235/Interview...
# 2   {'id': 583675202, 'name': '19920513/www', 'url...
# 3   {'id': 522779339, 'name': 'curseforge-mirror/r...
# 4   {'id': 662499999, 'name': 'oci-sunbird/ocisunb...
# 5   {'id': 662294388, 'name': 'nikhanal/tcioe-node...
# 6   {'id': 552661142, 'name': 'hwchase17/langchain...
# 7   {'id': 530821975, 'name': 'Altinity/clickhouse...
# 8   {'id': 662492653, 'name': 'h4mz411y/OrangeTask...
# 9   {'id': 583677093, 'name': '19920513/ntdtv', 'u...
# 10  {'id': 613363386, 'name': 'ZwierzchowskiM/Zwie...
# 11  {'id': 648803933, 'name': 'Haelios/Projet_7_OC...
# 12  {'id': 659197746, 'name': 'timazloy/React-pizz...
# 13  {'id': 662500387, 'name': 'Dimablock69/1', 'ur...
# 14  {'id': 662408234, 'name': 'T4O6N/payroll-c-', ...
# 15  {'id': 4454793, 'name': 'musescore/MuseScore',...
# 16  {'id': 662500384, 'name': 'topsberwite/Mondria...
# 17  {'id': 649686746, 'name': 'khaoula-berrah/alx-...
# 18  {'id': 201089574, 'name': 'pfasante/phd_thesis...
# 19  {'id': 47093357, 'name': 'ant-design/ant-desig...
# 20  {'id': 653616104, 'name': 'eunbinpark/Bitedu',...
# 21  {'id': 637620590, 'name': 'form8ion/repository...
# 22  {'id': 662294388, 'name': 'nikhanal/tcioe-node...
# 23  {'id': 28246472, 'name': 'shaka-project/shaka-...
# 24  {'id': 624092546, 'name': 'etherealelement/rss...
# 25  {'id': 657492571, 'name': 'TiffanyGB/myapp', '...
# 26  {'id': 662499999, 'name': 'oci-sunbird/ocisunb...
# 27  {'id': 68287594, 'name': 'academicpages/academ...
# 28  {'id': 562080230, 'name': 'mengisok/mengisok',...
# 29  {'id': 522779339, 'name': 'curseforge-mirror/r...
#
#                                               payload  public  \
# 0   {'repository_id': 661710037, 'push_id': 142111...    True
# 1   {'repository_id': 661281119, 'push_id': 142111...    True
# 2   {'repository_id': 583675202, 'push_id': 142111...    True
# 3   {'ref': 'v2023.07.05.09.13', 'ref_type': 'tag'...    True
# 4   {'ref': 'release-2.10.1', 'ref_type': 'branch'...    True
# 5   {'repository_id': 662294388, 'push_id': 142111...    True
# 6   {'action': 'created', 'issue': {'url': 'https:...    True
# 7   {'repository_id': 530821975, 'push_id': 142111...    True
# 8   {'repository_id': 662492653, 'push_id': 142111...    True
# 9   {'repository_id': 583677093, 'push_id': 142111...    True
# 10  {'repository_id': 613363386, 'push_id': 142111...    True
# 11  {'repository_id': 648803933, 'push_id': 142111...    True
# 12  {'repository_id': 659197746, 'push_id': 142111...    True
# 13  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 14  {'repository_id': 662408234, 'push_id': 142111...    True
# 15  {'action': 'created', 'issue': {'url': 'https:...    True
# 16  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 17  {'repository_id': 649686746, 'push_id': 142111...    True
# 18                              {'action': 'started'}    True
# 19  {'action': 'created', 'review': {'id': 1514050...    True
# 20  {'repository_id': 653616104, 'push_id': 142111...    True
# 21  {'action': 'opened', 'number': 69, 'pull_reque...    True
# 22  {'repository_id': 662294388, 'push_id': 142111...    True
# 23  {'action': 'created', 'issue': {'url': 'https:...    True
# 24  {'repository_id': 624092546, 'push_id': 142111...    True
# 25  {'repository_id': 657492571, 'push_id': 142111...    True
# 26  {'ref': 'release-3.1.0', 'ref_type': 'branch',...    True
# 27  {'forkee': {'id': 662500383, 'node_id': 'R_kgD...    True
# 28  {'repository_id': 562080230, 'push_id': 142111...    True
# 29  {'action': 'published', 'release': {'url': 'ht...    True
#
#               created_at                                                org
# 0   2023-07-05T09:13:36Z                                                NaN
# 1   2023-07-05T09:13:36Z                                                NaN
# 2   2023-07-05T09:13:36Z                                                NaN
# 3   2023-07-05T09:13:36Z  {'id': 110800464, 'login': 'curseforge-mirror'...
# 4   2023-07-05T09:13:36Z  {'id': 133922262, 'login': 'oci-sunbird', 'gra...
# 5   2023-07-05T09:13:36Z                                                NaN
# 6   2023-07-05T09:13:36Z                                                NaN
# 7   2023-07-05T09:13:36Z  {'id': 28471076, 'login': 'Altinity', 'gravata...
# 8   2023-07-05T09:13:36Z                                                NaN
# 9   2023-07-05T09:13:36Z                                                NaN
# 10  2023-07-05T09:13:36Z                                                NaN
# 11  2023-07-05T09:13:36Z                                                NaN
# 12  2023-07-05T09:13:36Z                                                NaN
# 13  2023-07-05T09:13:36Z                                                NaN
# 14  2023-07-05T09:13:36Z                                                NaN
# 15  2023-07-05T09:13:36Z  {'id': 380563, 'login': 'musescore', 'gravatar...
# 16  2023-07-05T09:13:36Z                                                NaN
# 17  2023-07-05T09:13:36Z                                                NaN
# 18  2023-07-05T09:13:36Z                                                NaN
# 19  2023-07-05T09:13:36Z  {'id': 12101536, 'login': 'ant-design', 'grava...
# 20  2023-07-05T09:13:36Z                                                NaN
# 21  2023-07-05T09:13:36Z  {'id': 49035156, 'login': 'form8ion', 'gravata...
# 22  2023-07-05T09:13:36Z                                                NaN
# 23  2023-07-05T09:13:36Z  {'id': 99903801, 'login': 'shaka-project', 'gr...
# 24  2023-07-05T09:13:36Z                                                NaN
# 25  2023-07-05T09:13:36Z                                                NaN
# 26  2023-07-05T09:13:36Z  {'id': 133922262, 'login': 'oci-sunbird', 'gra...
# 27  2023-07-05T09:13:36Z  {'id': 22107085, 'login': 'academicpages', 'gr...
# 28  2023-07-05T09:13:36Z                                                NaN
# 29  2023-07-05T09:13:36Z  {'id': 110800464, 'login': 'curseforge-mirror'...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                    type  public            created_at  \
# 0   30205608196               PushEvent    True  2023-07-05T09:13:36Z
# 1   30205608154               PushEvent    True  2023-07-05T09:13:36Z
# 2   30205608153               PushEvent    True  2023-07-05T09:13:36Z
# 3   30205608214             CreateEvent    True  2023-07-05T09:13:36Z
# 4   30205608197             CreateEvent    True  2023-07-05T09:13:36Z
# 5   30205608090               PushEvent    True  2023-07-05T09:13:36Z
# 6   30205608181       IssueCommentEvent    True  2023-07-05T09:13:36Z
# 7   30205608066               PushEvent    True  2023-07-05T09:13:36Z
# 8   30205608139               PushEvent    True  2023-07-05T09:13:36Z
# 9   30205608147               PushEvent    True  2023-07-05T09:13:36Z
# 10  30205608076               PushEvent    True  2023-07-05T09:13:36Z
# 11  30205608121               PushEvent    True  2023-07-05T09:13:36Z
# 12  30205608129               PushEvent    True  2023-07-05T09:13:36Z
# 13  30205608146             CreateEvent    True  2023-07-05T09:13:36Z
# 14  30205608123               PushEvent    True  2023-07-05T09:13:36Z
# 15  30205608128       IssueCommentEvent    True  2023-07-05T09:13:36Z
# 16  30205608064             CreateEvent    True  2023-07-05T09:13:36Z
# 17  30205608042               PushEvent    True  2023-07-05T09:13:36Z
# 18  30205608092              WatchEvent    True  2023-07-05T09:13:36Z
# 19  30205608068  PullRequestReviewEvent    True  2023-07-05T09:13:36Z
# 20  30205608046               PushEvent    True  2023-07-05T09:13:36Z
# 21  30205608119        PullRequestEvent    True  2023-07-05T09:13:36Z
# 22  30205608038               PushEvent    True  2023-07-05T09:13:36Z
# 23  30205608006       IssueCommentEvent    True  2023-07-05T09:13:36Z
# 24  30205608023               PushEvent    True  2023-07-05T09:13:36Z
# 25  30205608021               PushEvent    True  2023-07-05T09:13:36Z
# 26  30205608079             CreateEvent    True  2023-07-05T09:13:36Z
# 27  30205608051               ForkEvent    True  2023-07-05T09:13:36Z
# 28  30205608027               PushEvent    True  2023-07-05T09:13:36Z
# 29  30205607988            ReleaseEvent    True  2023-07-05T09:13:36Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0     4139601                 CaF2                CaF2
# 1   109524200            Pragna235           Pragna235
# 2   120438850             19920513            19920513
# 3    41898282  github-actions[bot]      github-actions
# 4    23467024           heungheung          heungheung
# 5    66510055             nikhanal            nikhanal
# 6    47170309             ybbthou8            ybbthou8
# 7    26748221              Selfeer             Selfeer
# 8    97634377             h4mz411y            h4mz411y
# 9   120438850             19920513            19920513
# 10   41898282  github-actions[bot]      github-actions
# 11  133202042              Haelios             Haelios
# 12   83652913             timazloy            timazloy
# 13  138666143          Dimablock69         Dimablock69
# 14  100561809                T4O6N               T4O6N
# 15    1786669         Jojo-Schmitz        Jojo-Schmitz
# 16  138441805          topsberwite         topsberwite
# 17  125555048       khaoula-berrah      khaoula-berrah
# 18   81730001               lhsnam              lhsnam
# 19    5378891              zombieJ             zombieJ
# 20   52900978           eunbinpark          eunbinpark
# 21   29139614        renovate[bot]            renovate
# 22   66510055             nikhanal            nikhanal
# 23     877455             enjikaka            enjikaka
# 24   95530911      etherealelement     etherealelement
# 25  106835730            TiffanyGB           TiffanyGB
# 26   23467024           heungheung          heungheung
# 27   35567571                lrgao               lrgao
# 28   41898282  github-actions[bot]      github-actions
# 29   41898282  github-actions[bot]      github-actions
#
#                                            actor.url  \
# 0                  https://api.github.com/users/CaF2
# 1             https://api.github.com/users/Pragna235
# 2              https://api.github.com/users/19920513
# 3   https://api.github.com/users/github-actions[bot]
# 4            https://api.github.com/users/heungheung
# 5              https://api.github.com/users/nikhanal
# 6              https://api.github.com/users/ybbthou8
# 7               https://api.github.com/users/Selfeer
# 8              https://api.github.com/users/h4mz411y
# 9              https://api.github.com/users/19920513
# 10  https://api.github.com/users/github-actions[bot]
# 11              https://api.github.com/users/Haelios
# 12             https://api.github.com/users/timazloy
# 13          https://api.github.com/users/Dimablock69
# 14                https://api.github.com/users/T4O6N
# 15         https://api.github.com/users/Jojo-Schmitz
# 16          https://api.github.com/users/topsberwite
# 17       https://api.github.com/users/khaoula-berrah
# 18               https://api.github.com/users/lhsnam
# 19              https://api.github.com/users/zombieJ
# 20           https://api.github.com/users/eunbinpark
# 21        https://api.github.com/users/renovate[bot]
# 22             https://api.github.com/users/nikhanal
# 23             https://api.github.com/users/enjikaka
# 24      https://api.github.com/users/etherealelement
# 25            https://api.github.com/users/TiffanyGB
# 26           https://api.github.com/users/heungheung
# 27                https://api.github.com/users/lrgao
# 28  https://api.github.com/users/github-actions[bot]
# 29  https://api.github.com/users/github-actions[bot]
#
#                                      actor.avatar_url  ...  \
# 0    https://avatars.githubusercontent.com/u/4139601?  ...
# 1   https://avatars.githubusercontent.com/u/109524...  ...
# 2   https://avatars.githubusercontent.com/u/120438...  ...
# 3   https://avatars.githubusercontent.com/u/41898282?  ...
# 4   https://avatars.githubusercontent.com/u/23467024?  ...
# 5   https://avatars.githubusercontent.com/u/66510055?  ...
# 6   https://avatars.githubusercontent.com/u/47170309?  ...
# 7   https://avatars.githubusercontent.com/u/26748221?  ...
# 8   https://avatars.githubusercontent.com/u/97634377?  ...
# 9   https://avatars.githubusercontent.com/u/120438...  ...
# 10  https://avatars.githubusercontent.com/u/41898282?  ...
# 11  https://avatars.githubusercontent.com/u/133202...  ...
# 12  https://avatars.githubusercontent.com/u/83652913?  ...
# 13  https://avatars.githubusercontent.com/u/138666...  ...
# 14  https://avatars.githubusercontent.com/u/100561...  ...
# 15   https://avatars.githubusercontent.com/u/1786669?  ...
# 16  https://avatars.githubusercontent.com/u/138441...  ...
# 17  https://avatars.githubusercontent.com/u/125555...  ...
# 18  https://avatars.githubusercontent.com/u/81730001?  ...
# 19   https://avatars.githubusercontent.com/u/5378891?  ...
# 20  https://avatars.githubusercontent.com/u/52900978?  ...
# 21  https://avatars.githubusercontent.com/u/29139614?  ...
# 22  https://avatars.githubusercontent.com/u/66510055?  ...
# 23    https://avatars.githubusercontent.com/u/877455?  ...
# 24  https://avatars.githubusercontent.com/u/95530911?  ...
# 25  https://avatars.githubusercontent.com/u/106835...  ...
# 26  https://avatars.githubusercontent.com/u/23467024?  ...
# 27  https://avatars.githubusercontent.com/u/35567571?  ...
# 28  https://avatars.githubusercontent.com/u/41898282?  ...
# 29  https://avatars.githubusercontent.com/u/41898282?  ...
#
#     payload.release.draft payload.release.prerelease  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
# 5                     NaN                        NaN
# 6                     NaN                        NaN
# 7                     NaN                        NaN
# 8                     NaN                        NaN
# 9                     NaN                        NaN
# 10                    NaN                        NaN
# 11                    NaN                        NaN
# 12                    NaN                        NaN
# 13                    NaN                        NaN
# 14                    NaN                        NaN
# 15                    NaN                        NaN
# 16                    NaN                        NaN
# 17                    NaN                        NaN
# 18                    NaN                        NaN
# 19                    NaN                        NaN
# 20                    NaN                        NaN
# 21                    NaN                        NaN
# 22                    NaN                        NaN
# 23                    NaN                        NaN
# 24                    NaN                        NaN
# 25                    NaN                        NaN
# 26                    NaN                        NaN
# 27                    NaN                        NaN
# 28                    NaN                        NaN
# 29                  False                      False
#
#    payload.release.created_at  payload.release.published_at  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
# 21                        NaN                           NaN
# 22                        NaN                           NaN
# 23                        NaN                           NaN
# 24                        NaN                           NaN
# 25                        NaN                           NaN
# 26                        NaN                           NaN
# 27                        NaN                           NaN
# 28                        NaN                           NaN
# 29       2023-04-27T00:28:41Z          2023-07-05T09:13:35Z
#
#     payload.release.assets                        payload.release.tarball_url  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                                                NaN
# 7                      NaN                                                NaN
# 8                      NaN                                                NaN
# 9                      NaN                                                NaN
# 10                     NaN                                                NaN
# 11                     NaN                                                NaN
# 12                     NaN                                                NaN
# 13                     NaN                                                NaN
# 14                     NaN                                                NaN
# 15                     NaN                                                NaN
# 16                     NaN                                                NaN
# 17                     NaN                                                NaN
# 18                     NaN                                                NaN
# 19                     NaN                                                NaN
# 20                     NaN                                                NaN
# 21                     NaN                                                NaN
# 22                     NaN                                                NaN
# 23                     NaN                                                NaN
# 24                     NaN                                                NaN
# 25                     NaN                                                NaN
# 26                     NaN                                                NaN
# 27                     NaN                                                NaN
# 28                     NaN                                                NaN
# 29                      []  https://api.github.com/repos/curseforge-mirror...
#
#                           payload.release.zipball_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://api.github.com/repos/curseforge-mirror...
#
#                                  payload.release.body  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  # RCLootCouncil Mirror\n\nThis is a mirror of ...
#
#                payload.release.short_description_html  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  <h1>RCLootCouncil Mirror</h1>\n<p>This is a mi...
#
#    payload.release.is_short_description_html_truncated
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                              False
#
# [30 rows x 638 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-now.json'

# %%
response.json()
# Out:
# {'timestamp': 1688548721,
#  'message': 'success',
#  'iss_position': {'longitude': '-18.1553', 'latitude': '16.6088'}}

# %% [markdown]
# {'latitude': '-51.1927', 'longitude': '145.6277'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"longitude": 52.53370520371973, "latitude": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 404

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 404

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/anaconda3/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/anaconda3/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 response.json()
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')
